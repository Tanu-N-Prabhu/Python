# %% [markdown]
# <a href="https://colab.research.google.com/github/Tanu-N-Prabhu/Python/blob/master/Data%20Analysis/Level%201/data_cleaning_techniques_in_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Cleaning Techniques with Pandas
#
# Cleaning your data is an essential first step in any data analysis process. Dirty data can mislead your models and visualizations. Below are the most common data cleaning techniques using Python and the Pandas library.
#
# ## 1. Handling Missing Data
# Real-world data is often incomplete. You need strategies to deal with missing values effectively.
#
# ### Detecting Missing Values

# %%
import pandas as pd

df = pd.DataFrame({
    'Name': ['Alice', 'Bob', None, 'David'],
    'Age': [25, None, 35, 40],
    'Score': [90, 85, None, 95]
})

print(df)
print(df.isnull())        # True wherever data is missing
print(df.isnull().sum())  # Count of missing values per column
# Out:
#     Name   Age  Score
# 0  Alice  25.0   90.0
# 1    Bob   NaN   85.0
# 2   None  35.0    NaN
# 3  David  40.0   95.0
#     Name    Age  Score
# 0  False  False  False
# 1  False   True  False
# 2   True  False   True
# 3  False  False  False
# Name     1
# Age      1
# Score    1
# dtype: int64

# %% [markdown]
# ### Removing Missing Data
# Remove rows where any value is missing:

# %%
df_cleaned = df.dropna()
df_cleaned
# Out:
#     Name   Age  Score
# 0  Alice  25.0   90.0
# 3  David  40.0   95.0

# %% [markdown]
# ### Remove rows where all values are missing:

# %%
df_cleaned = df.dropna(how='all')
df_cleaned
# Out:
#     Name   Age  Score
# 0  Alice  25.0   90.0
# 1    Bob   NaN   85.0
# 2   None  35.0    NaN
# 3  David  40.0   95.0

# %% [markdown]
# ### Remove columns with missing values:

# %%
df_cleaned = df.dropna(axis=1)
df_cleaned
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3]

# %% [markdown]
# ###  Filling Missing Data
#
# Fill with a constant:

# %%
df_filled = df.fillna(0)
df_filled
# Out:
#     Name   Age  Score
# 0  Alice  25.0   90.0
# 1    Bob   0.0   85.0
# 2      0  35.0    0.0
# 3  David  40.0   95.0

# %% [markdown]
# ### Forward fill (propagate last valid value forward):

# %%
df_filled = df.fillna(method='ffill')
df_filled
# Out:
# /tmp/ipython-input-7-685454775.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_filled = df.fillna(method='ffill')
#     Name   Age  Score
# 0  Alice  25.0   90.0
# 1    Bob  25.0   85.0
# 2    Bob  35.0   85.0
# 3  David  40.0   95.0

# %% [markdown]
# ### Backward fill (propagate next valid value backward):

# %%
df_filled = df.fillna(method='bfill')
df_filled
# Out:
# /tmp/ipython-input-8-3373720968.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_filled = df.fillna(method='bfill')
#     Name   Age  Score
# 0  Alice  25.0   90.0
# 1    Bob  35.0   85.0
# 2  David  35.0   95.0
# 3  David  40.0   95.0

# %% [markdown]
# ### Fill with mean/median:

# %%
df['Age'].fillna(df['Age'].mean(), inplace=True)
df
# Out:
# /tmp/ipython-input-9-1943981980.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(df['Age'].mean(), inplace=True)
#     Name        Age  Score
# 0  Alice  25.000000   90.0
# 1    Bob  33.333333   85.0
# 2   None  35.000000    NaN
# 3  David  40.000000   95.0

# %% [markdown]
# ## 2. Detecting and Fixing Incorrect or Inconsistent Data
#
# Bad entries often sneak in, especially with strings.
#
# ### Common Issues:
# - Typos (e.g., `"calgary"` vs `"Calgary"`)
#
# - Case sensitivity (`"YES"` vs `"yes"`)
#
# - Unexpected characters or symbols
#
# ### Example: Fixing inconsistent categories

# %%
df = pd.DataFrame({'City': ['Calgary', 'calgary', 'Toronto', 'Vancouver', 'Calgary']})

# Standardize to lowercase
df['City'] = df['City'].str.lower()

# Capitalize consistently
df['City'] = df['City'].str.title()

df
# Out:
#         City
# 0    Calgary
# 1    Calgary
# 2    Toronto
# 3  Vancouver
# 4    Calgary

# %% [markdown]
# ## 3. Handling Duplicate Data
# Duplicate rows can bias your results or skew aggregates.
#
# ### Detecting Duplicates

# %%
df.duplicated()
df.duplicated().sum()
# Out:
# np.int64(2)

# %% [markdown]
# ### Removing Duplicates

# %%
df_unique = df.drop_duplicates()
df_unique
# Out:
#         City
# 0    Calgary
# 2    Toronto
# 3  Vancouver

# %% [markdown]
# ### Remove duplicates based on a specific column:

# %%
df_unique = df.drop_duplicates(subset='City')
df_unique
# Out:
#         City
# 0    Calgary
# 2    Toronto
# 3  Vancouver

# %% [markdown]
# ### Keep the last occurrence:

# %%
df_unique = df.drop_duplicates(keep='last')
df_unique
# Out:
#         City
# 2    Toronto
# 3  Vancouver
# 4    Calgary

# %% [markdown]
# ## Summary
#
# | Task                     | Method                              |
# | ------------------------ | ----------------------------------- |
# | Detect missing values    | `isnull()`, `notnull()`             |
# | Remove missing data      | `dropna()`                          |
# | Fill missing data        | `fillna()`                          |
# | Detect incorrect values  | `.unique()`, `.value_counts()`      |
# | Normalize strings        | `.str.lower()`, `.str.title()`      |
# | Detect/Remove duplicates | `duplicated()`, `drop_duplicates()` |
#
#
# ## Best Practices
# - Always inspect your data with `.info()` and `.describe()` first.
#
# - Use `.isnull()` `.sum()` to detect where missing values occur.
#
# - Be cautious when dropping or filling data, you may unintentionally bias your dataset.
#
# - Normalize string data before running analyses or merges.
