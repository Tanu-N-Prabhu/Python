# %% [markdown]
# <a href="https://colab.research.google.com/github/Tanu-N-Prabhu/Python/blob/master/Data%20Analysis/Level%202/correlation_covariance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Correlation & Covariance**
#
# _Correlation and covariance are essential tools for understanding relationships between numerical variables._
#
#
# ## What You'll Learn
# - What correlation and covariance mean
# - How to compute them in pandas
# - How to visualize relationships using a heatmap
#
# ## Concepts
# - **Correlation**: Measures the strength and direction of a linear relationship between two variables. Ranges between -1 and 1.
#
# - **Covariance**: Measures how two variables vary together. Units are not standardized, unlike correlation.
#
#
# ## Import Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Sample Dataset
# We’ll create a small DataFrame to work with:

# %%
data = {
    'Hours_Studied': [1, 2, 3, 4, 5, 6, 7],
    'Exam_Score': [50, 55, 65, 70, 75, 85, 90],
    'Sleep_Hours': [8, 7, 6, 6, 5, 4, 3]
}

df = pd.DataFrame(data)
df
# Out:
#    Hours_Studied  Exam_Score  Sleep_Hours
# 0              1          50            8
# 1              2          55            7
# 2              3          65            6
# 3              4          70            6
# 4              5          75            5
# 5              6          85            4
# 6              7          90            3

# %% [markdown]
# ### 1. Correlation - .corr()

# %%
df.corr()
# Out:
#                Hours_Studied  Exam_Score  Sleep_Hours
# Hours_Studied       1.000000    0.995871    -0.987829
# Exam_Score          0.995871    1.000000    -0.988457
# Sleep_Hours        -0.987829   -0.988457     1.000000

# %% [markdown]
# Interpretation:
#
# - `Hours_Studied` and `Exam_Score` should show a strong positive correlation.
#
# - `Sleep_Hours` and `Hours_Studied` should show a negative correlation (studying more → less sleep).
#
#
# #### Visualizing Correlation

# %%
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# > This heatmap helps spot strong/weak correlations visually.
#
# ### 2. Covariance – .cov()

# %%
df.cov()
# Out:
#                Hours_Studied  Exam_Score  Sleep_Hours
# Hours_Studied       4.666667   31.666667    -3.666667
# Exam_Score         31.666667  216.666667   -25.000000
# Sleep_Hours        -3.666667  -25.000000     2.952381

# %% [markdown]
# - Covariance is not normalized and depends on the units of measurement.
#
# - Large values ≠ strong relationship. Always check correlation for that.
#
# ## When to Use
#
# | Use Case                  | Use         |
# |:------------------------- |:----------- |
# | Normalize strength        | Correlation |
# | Understand joint movement | Covariance  |
#
#
# ## Summary
#
# | Concept     | Description                     | Range   |
# |:----------- |:------------------------------- |:------- |
# | Correlation | Strength of linear relationship | -1 to 1 |
# | Covariance  | Direction of joint variation    | -∞ to ∞ |
#
#
# ## Exercise
# Try it with your own dataset (e.g., Titanic, Iris, etc.):
#
# ```python
# df = pd.read_csv('your_dataset.csv')
# print(df.corr())
# ```
