# %% [markdown]
# <a href="https://colab.research.google.com/github/Tanu-N-Prabhu/Python/blob/master/Doubt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www.ratemyprofessors.com/ShowRatings.jsp?tid=155191&showMyProfs=true'

# %%
page = requests.get(url)
page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.text, "html.parser")
soup
# Out:
# <!DOCTYPE html>
#
# <!--[if lt IE 7]>      <html class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>         <html class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>         <html class="no-js lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!--> <html class="no-js"> <!--<![endif]-->
# <head>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="F8gUuqzRvOrAlhaGyP7aAuMs_Se8zK-98Ai2sNsIZEo" name="google-site-verification">
# <meta content="hk1NnSbYuDC0Sppgbf7YIT-VxUiRbOVRdtqA4AmkGzM" name="google-site-verification"/>
# <meta content="CKMC_IwvKoVbX1U8x1A9yzKABsSlop6qxfuDzwfV7Qs" name="google-site-verification"/> <!--  relaunch qa -->
# <meta content="1D_3ZfAdMu4Tki8pFRj68YAqYot-paTOoDVzCTIJZZI" name="google-site-verification"/> <!--  relaunch rmp -->
# <meta content="14147781149-i5ph5oqooelp3k0qfrb3jkk6vs4528ha.apps.googleusercontent.com" name="google-signin-client_id"/>
# <script type="text/javascript">
# </script>
# ...

# %% [markdown]
# # To find the Comments (tag) of the professor use this.

# %%
proftags = soup.findAll("span", {"class": "tag-box-choosetags" })
proftags
# Out:
# [<span class="tag-box-choosetags"> Skip class? You won't pass. <b>(17)</b></span>,
#  <span class="tag-box-choosetags"> Tough grader <b>(13)</b></span>,
#  <span class="tag-box-choosetags"> Participation matters <b>(8)</b></span>,
#  <span class="tag-box-choosetags"> Caring <b>(6)</b></span>,
#  <span class="tag-box-choosetags"> Graded by few things <b>(5)</b></span>,
#  <span class="tag-box-choosetags"> Clear grading criteria <b>(5)</b></span>,
#  <span class="tag-box-choosetags"> Accessible outside class <b>(4)</b></span>,
#  <span class="tag-box-choosetags"> So many papers <b>(3)</b></span>,
#  <span class="tag-box-choosetags"> Lecture heavy <b>(2)</b></span>,
#  <span class="tag-box-choosetags"> Hilarious <b>(2)</b></span>,
#  <span class="tag-box-choosetags"> Gives good feedback <b>(2)</b></span>,
#  <span class="tag-box-choosetags"> EXTRA CREDIT <b>(1)</b></span>,
#  <span class="tag-box-choosetags"> Amazing lectures <b>(1)</b></span>,
# ...

# %% [markdown]
# # To find the ratings of the professor

# %%
proftags1 = soup.findAll("span", {"class": "rating-type" })
proftags1
# Out:
# [<span class="rating-type">awful</span>,
#  <span class="rating-type">awful</span>,
#  <span class="rating-type">poor</span>,
#  <span class="rating-type">awesome</span>,
#  <span class="rating-type">awful</span>,
#  <span class="rating-type">awesome</span>,
#  <span class="rating-type">good</span>,
#  <span class="rating-type">awesome</span>,
#  <span class="rating-type">average</span>,
#  <span class="rating-type">awesome</span>,
#  <span class="rating-type">awesome</span>,
#  <span class="rating-type">awesome</span>,
#  <span class="rating-type">awesome</span>,
#  <span class="rating-type">average</span>,
#  <span class="rating-type">awesome</span>,
#  <span class="rating-type">good</span>,
#  <span class="rating-type">awful</span>,
#  <span class="rating-type">good</span>,
#  <span class="rating-type">awesome</span>,
#  <span class="rating-type">awesome</span>]

# %%
proftags2 = soup.findAll("span", {"class": "score poor"})
proftags2
# Out:
# [<span class="score poor">1.0</span>,
#  <span class="score poor">1.0</span>,
#  <span class="score poor">1.0</span>,
#  <span class="score poor">1.0</span>]

# %%
proftags2 = soup.findAll("span", {"class": "score average"})
proftags2
# Out:
# [<span class="score average">2.0</span>,
#  <span class="score average">3.0</span>,
#  <span class="score average">3.0</span>]

# %% [markdown]
# ---

# %% [markdown]
# # To find all the comments use this

# %%
proftags2 = soup.findAll("p", {"class": "commentsParagraph"})
proftags2
# Out:
# [<p class="commentsParagraph">
#                        She's an academic (in the most insulting sense). Her papers give overly rigorous specifications for how to get an A. You don't actually need to understand your topic, as long as you can find professors like her to cite within it, she will be happy.
#                    </p>, <p class="commentsParagraph">
#                        Ive never met a more exhausting professor. Shes the worst combination of being overly excited about the material while also teaching you nothing of substance. The paper and presentation guidelines are the length of books but still gloss over things she expects in them. Thank god this class only met once a week
#                    </p>, <p class="commentsParagraph">
# ...

# %% [markdown]
# # Finally to parse it as a text use this

# %%
for mytag in proftags:
  comments = mytag.get_text()
  print(comments)
# Out:
#  Skip class? You won't pass. (17)
#  Tough grader (13)
#  Participation matters (8)
#  Caring (6)
#  Graded by few things (5)
#  Clear grading criteria (5)
#  Accessible outside class (4)
#  So many papers (3)
#  Lecture heavy (2)
#  Hilarious (2)
#  Gives good feedback (2)
#  EXTRA CREDIT (1)
#  Amazing lectures (1)
#  Get ready to read (1)
#  Respected (1)
#  Lots of homework (1)

# %% [markdown]
# First, if you want to find any particular reviews, comments or ratings press Ctrl F to find the reviews, comments or ratings view inside the scraped tags. For example, in this case, if you want to find the comments as " She's an academic (in the most insulting sense). Her papers give overly rigorous specifications for how to get an A. You don't actually need to understand your topic, as long as you can find professors like her to cite within it, she will be happy." then copy paste the entire comments by pressing the Ctrl - F inside the scraped text (soup) in this case. Then copy the tag and the class then you will get your desired output.

# %% [markdown]
# So I dont know how to convert the raw data into the .csv file. However I tried storing it in the pandas data frame but only one line was getting stored. I'll get back to you once when I get this thing. But for now just surf through the link given below, maybe you can get your answer.
#
# [Link](https://stackoverflow.com/questions/3345336/save-results-to-csv-file-with-python)
