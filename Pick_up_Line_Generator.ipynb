# %% [markdown]
# <a href="https://colab.research.google.com/github/Tanu-N-Prabhu/Python/blob/master/Pick_up_Line_Generator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pick-Up Line Generator using Python Dictionaries
# ## This works for real!
#
# ![mindy-sabiston-9hgDf95TNO8-unsplash.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # Introduction
# Python dictionaries are used to store data via `key : value` pair. In this tutorial, we shall learn how to store the data in a dictionary and extend it to create a simple pick-up line generator application. Dictionaries are mutable data structures. Mutable data structures are those whose values can be modified after creation.
#
# ---
#
# # Steps to implement the generator
# 1. Importing the `random` library
# 2. Creation of a dictionary that holds the values
# 3. Retrieving the key value as a tuple in a list
# 4. Randomizing the selected element from the specified sequence
# 5. Printing the value of the returned dictionary value
#
# ---
#
# # Implementation
# Let's put all the above steps into action.
#
# ## Importing the Random Library
# The `random` library is one of Python's best built-in modules that can be used to return random values. There are plenty of methods inside this module. Feel free to surf around.
#
# [Python Random Module](https://www.w3schools.com/python/module_random.asp)
#
# To use the `random` library all you need to do is import it as shown below.

# %%
import random

# %% [markdown]
# ## Creation of a dictionary that holds the values
# This step is simple, all you need to do is create a dictionary `d` that holds the data in the form of a `key:value` pair.

# %%
d = { '1': 'Are you a parking ticket? Cause youve got fine written all over you.',
      '2': 'Are you from Tennessee? Because you are the only 10 I see.',
      '3': 'Are you sure you are not tired? You have been running through my mind all day',
      '4':  'Im not a photographer, but I can picture me and you together.',
      '5':  'Im lost. Can you give me directions to your heart?',
      '6':  'Did it hurt? When you fell from heaven?',
      '7':  'If I could rearrange the alphabet, Id put "U" and "I" together.',
      '8':  'Well, here I am. What are your other two wishes?',
      '9':  'Its a good thing I have my library card, because I am totally checking you out.',
      '10':  'They say Disney World is the happiest place on Earth, but clearly they have never stood next to you.'
}

# %% [markdown]
# ## Retrieving the key value as a tuple in a list
# For this, we can use the `item()` method that returns a view object. This object contains the key-value pairs as a tuple in a list. Let's see a simple example to understand this concept.

# %%
car = {
  "brand": "Mercedes Benz",
  "model": "S - Class",
  "year": 2023
}

x = car.items()

print(x)
# Out:
# dict_items([('brand', 'Mercedes Benz'), ('model', 'S - Class'), ('year', 2023)])

# %% [markdown]
# Now the view object is also dynamic, any changes made to the dictionary will reflect in the view object.

# %%
car["year"] = 2024
print(x)
# Out:
# dict_items([('brand', 'Mercedes Benz'), ('model', 'S - Class'), ('year', 2024)])

# %% [markdown]
# Going back to the generator the way we can implement it is by saying

# %%
list(d.items())
# Out:
# [('1', 'Are you a parking ticket? Cause youve got fine written all over you.'),
#  ('2', 'Are you from Tennessee? Because you are the only 10 I see.'),
#  ('3',
#   'Are you sure you are not tired? You have been running through my mind all day'),
#  ('4', 'Im not a photographer, but I can picture me and you together.'),
#  ('5', 'Im lost. Can you give me directions to your heart?'),
#  ('6', 'Did it hurt? When you fell from heaven?'),
#  ('7', 'If I could rearrange the alphabet, Id put "U" and "I" together.'),
#  ('8', 'Well, here I am. What are your other two wishes?'),
#  ('9',
#   'Its a good thing I have my library card, because I am totally checking you out.'),
#  ('10',
#   'They say Disney World is the happiest place on Earth, but clearly they have never stood next to you.')]

# %% [markdown]
# ## Randomizing the selected element from the specified sequence
# Let's use the `random` module. As the name suggests it's pretty self-explanatory. For example.

# %%
import random

print(random.random())
# Out:
# 0.06708847826872866

# %% [markdown]
# In this case, we would write the function as

# %%
random.choice(list(d.items()))
# Out:
# ('4', 'Im not a photographer, but I can picture me and you together.')

# %% [markdown]
# ## Printing the value of the returned dictionary value
# A dictionary as discussed above comprises a `key-value` pair. So to return the value you need to write.

# %%
key, value = random.choice(list(d.items()))
value
# Out:
# 'Are you from Tennessee? Because you are the only 10 I see.'

# %% [markdown]
# Now the value returned would be a dictionary value except for the key. You can always print the `key` to see its return and then map it to the value in the dictionary declared.
#
# ---
#
# # Conclusion
# This concluded the article by understanding the concept of a dictionary and its usage along with the `random` library. This is just the introduction of a giant concept in the Python world. Let me know if you have any comments, questions, or suggestions in the comment section below. Thanks for reading the article. See you soon. Until then, have a great day.
